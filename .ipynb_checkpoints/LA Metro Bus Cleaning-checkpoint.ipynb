# %% [markdown]
# # LA Metro Bus Data Cleaning
# I have data from the following days that need to be cleaned: 7/16, 7/17, 7/18, 7/20, 7/22

# %%
import pandas as pd

# %%
bus_df = pd.read_csv("../Bus Data/LAMetro_bus_data.csv")
bus_df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-7af854a16e26> in <module>
# ----> 1 bus_df = pd.read_csv("../Bus Data/LAMetro_bus_data.csv")
#       2 bus_df
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     446
#     447     # Create the parser.
# --> 448     parser = TextFileReader(fp_or_buf, **kwds)
#     449
#     450     if chunksize or iterator:
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     878             self.options["has_index_names"] = kwds["has_index_names"]
#     879
# --> 880         self._make_engine(self.engine)
#     881
#     882     def close(self):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1112     def _make_engine(self, engine="c"):
#    1113         if engine == "c":
# -> 1114             self._engine = CParserWrapper(self.f, **self.options)
#    1115         else:
#    1116             if engine == "python":
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1889         kwds["usecols"] = self.usecols
#    1890
# -> 1891         self._reader = parsers.TextReader(src, **kwds)
#    1892         self.unnamed_cols = self._reader.unnamed_cols
#    1893
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: [Errno 2] File ../Bus Data/LAMetro_bus_data.csv does not exist: '../Bus Data/LAMetro_bus_data.csv'

# %% [markdown]
# I need to change the grouped time and actual time to datetime format

# %%
bus_df["grouped time"] = bus_df["grouped time"].apply(pd.to_datetime)
bus_df["actual time"] = bus_df["actual time"].apply(pd.to_datetime)

# %%
bus_df.dtypes
# Out:
# grouped time    datetime64[ns]
# actual time     datetime64[ns]
# last report              int64
# id                       int64
# route                  float64
# latitude               float64
# longitude              float64
# run                     object
# dtype: object

# %% [markdown]
# I am also going to make an hour column

# %%
bus_df["hour"] = bus_df["actual time"].map(lambda x: x.hour)
bus_df
# Out:
#                      grouped time                actual time  last report  \
# 0      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.605064            8
# 1      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.786010            8
# 2      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.957790            8
# 3      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.153969          125
# 4      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.334927           37
# ...                           ...                        ...          ...
# 499872 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.623953          182
# 499873 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.900232           18
# 499874 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.200471           44
# 499875 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.488402           44
# 499876 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.768894           45
#
#           id  route   latitude   longitude  \
# 0       1600  794.0  34.033451 -118.264847
# 1       4140  268.0  34.148680 -118.080071
# 2       4171   70.0  34.052975 -118.249674
# 3       4061  705.0  34.003990 -118.227187
# 4       9567  108.0  33.972591 -118.113319
# ...      ...    ...        ...         ...
# 499872  3945   14.0  34.076046 -118.359283
# 499873  3997   94.0  34.223754 -118.375764
# 499874  8592  166.0  34.249901 -118.606163
# 499875  1716   53.0  33.934093 -118.254295
# 499876  4135    4.0  34.077835 -118.262812
#
#                                             run  hour direction         day
# 0                       North to Sylmar Station     8     North  2020-07-16
# 1                     South to El Monte Station     8     South  2020-07-16
# 2                      East to El Monte Station     8      East  2020-07-16
# 3                       North to West Hollywood     8     North  2020-07-16
# 4                        West to Marina Del Rey     8      West  2020-07-16
# ...                                         ...   ...       ...         ...
# 499872  South to Washington/Fairfax Transit Hub    18     South  2020-07-22
# 499873                  North to Sylmar Station    18     North  2020-07-22
# 499874                       East to Sun Valley    18      East  2020-07-22
# 499875                  South to Avalon Station    18     South  2020-07-22
# 499876                     West to Santa Monica    18      West  2020-07-22
#
# [499877 rows x 11 columns]

# %% [markdown]
# I will now split the direction from the run column and make it its own column

# %%
direction_df = bus_df["run"].str.split(' ', n = 1, expand = True)
direction_df.columns = ["direction", "name"]
bus_df["direction"] = direction_df["direction"]
bus_df
# Out:
#                      grouped time                actual time  last report  \
# 0      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.605064            8
# 1      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.786010            8
# 2      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.957790            8
# 3      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.153969          125
# 4      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.334927           37
# ...                           ...                        ...          ...
# 499872 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.623953          182
# 499873 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.900232           18
# 499874 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.200471           44
# 499875 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.488402           44
# 499876 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.768894           45
#
#           id  route   latitude   longitude  \
# 0       1600  794.0  34.033451 -118.264847
# 1       4140  268.0  34.148680 -118.080071
# 2       4171   70.0  34.052975 -118.249674
# 3       4061  705.0  34.003990 -118.227187
# 4       9567  108.0  33.972591 -118.113319
# ...      ...    ...        ...         ...
# 499872  3945   14.0  34.076046 -118.359283
# 499873  3997   94.0  34.223754 -118.375764
# 499874  8592  166.0  34.249901 -118.606163
# 499875  1716   53.0  33.934093 -118.254295
# 499876  4135    4.0  34.077835 -118.262812
#
#                                             run  hour direction
# 0                       North to Sylmar Station     8     North
# 1                     South to El Monte Station     8     South
# 2                      East to El Monte Station     8      East
# 3                       North to West Hollywood     8     North
# 4                        West to Marina Del Rey     8      West
# ...                                         ...   ...       ...
# 499872  South to Washington/Fairfax Transit Hub    18     South
# 499873                  North to Sylmar Station    18     North
# 499874                       East to Sun Valley    18      East
# 499875                  South to Avalon Station    18     South
# 499876                     West to Santa Monica    18      West
#
# [499877 rows x 10 columns]

# %% [markdown]
# Here I am going to split the day from the actual time and make it its own column

# %%
day_df = bus_df["actual time"].astype(str).str.split(' ', n = 1, expand = True)
day_df.columns = ["day", "time"]
bus_df["day"] = day_df["day"]
bus_df
# Out:
#                      grouped time                actual time  last report  \
# 0      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.605064            8
# 1      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.786010            8
# 2      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.957790            8
# 3      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.153969          125
# 4      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.334927           37
# ...                           ...                        ...          ...
# 499872 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.623953          182
# 499873 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.900232           18
# 499874 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.200471           44
# 499875 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.488402           44
# 499876 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.768894           45
#
#           id  route   latitude   longitude  \
# 0       1600  794.0  34.033451 -118.264847
# 1       4140  268.0  34.148680 -118.080071
# 2       4171   70.0  34.052975 -118.249674
# 3       4061  705.0  34.003990 -118.227187
# 4       9567  108.0  33.972591 -118.113319
# ...      ...    ...        ...         ...
# 499872  3945   14.0  34.076046 -118.359283
# 499873  3997   94.0  34.223754 -118.375764
# 499874  8592  166.0  34.249901 -118.606163
# 499875  1716   53.0  33.934093 -118.254295
# 499876  4135    4.0  34.077835 -118.262812
#
#                                             run  hour direction         day
# 0                       North to Sylmar Station     8     North  2020-07-16
# 1                     South to El Monte Station     8     South  2020-07-16
# 2                      East to El Monte Station     8      East  2020-07-16
# 3                       North to West Hollywood     8     North  2020-07-16
# 4                        West to Marina Del Rey     8      West  2020-07-16
# ...                                         ...   ...       ...         ...
# 499872  South to Washington/Fairfax Transit Hub    18     South  2020-07-22
# 499873                  North to Sylmar Station    18     North  2020-07-22
# 499874                       East to Sun Valley    18      East  2020-07-22
# 499875                  South to Avalon Station    18     South  2020-07-22
# 499876                     West to Santa Monica    18      West  2020-07-22
#
# [499877 rows x 11 columns]

# %% [markdown]
# I am going to change all of the day values into their day of the week values

# %%
bus_df["day"].unique()
# Out:
# array(['2020-07-16', '2020-07-17', '2020-07-18', '2020-07-20',
#        '2020-07-22'], dtype=object)

# %%
bus_df['day'] = bus_df['day'].map({'2020-07-16' : 'Thursday',
                                   '2020-07-17' : 'Friday',
                                   '2020-07-18' : 'Saturday',
                                   '2020-07-20' : 'Monday',
                                   '2020-07-22' : 'Wednesday'
                                  })
bus_df
# Out:
#                      grouped time                actual time  last report  \
# 0      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.605064            8
# 1      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.786010            8
# 2      2020-07-16 08:54:29.410523 2020-07-16 08:54:30.957790            8
# 3      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.153969          125
# 4      2020-07-16 08:54:29.410523 2020-07-16 08:54:31.334927           37
# ...                           ...                        ...          ...
# 499872 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.623953          182
# 499873 2020-07-22 18:43:29.161669 2020-07-22 18:47:54.900232           18
# 499874 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.200471           44
# 499875 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.488402           44
# 499876 2020-07-22 18:43:29.161669 2020-07-22 18:47:55.768894           45
#
#           id  route   latitude   longitude  \
# 0       1600  794.0  34.033451 -118.264847
# 1       4140  268.0  34.148680 -118.080071
# 2       4171   70.0  34.052975 -118.249674
# 3       4061  705.0  34.003990 -118.227187
# 4       9567  108.0  33.972591 -118.113319
# ...      ...    ...        ...         ...
# 499872  3945   14.0  34.076046 -118.359283
# 499873  3997   94.0  34.223754 -118.375764
# 499874  8592  166.0  34.249901 -118.606163
# 499875  1716   53.0  33.934093 -118.254295
# 499876  4135    4.0  34.077835 -118.262812
#
#                                             run  hour direction        day
# 0                       North to Sylmar Station     8     North   Thursday
# 1                     South to El Monte Station     8     South   Thursday
# 2                      East to El Monte Station     8      East   Thursday
# 3                       North to West Hollywood     8     North   Thursday
# 4                        West to Marina Del Rey     8      West   Thursday
# ...                                         ...   ...       ...        ...
# 499872  South to Washington/Fairfax Transit Hub    18     South  Wednesday
# 499873                  North to Sylmar Station    18     North  Wednesday
# 499874                       East to Sun Valley    18      East  Wednesday
# 499875                  South to Avalon Station    18     South  Wednesday
# 499876                     West to Santa Monica    18      West  Wednesday
#
# [499877 rows x 11 columns]

# %%
bus_df.to_csv('[Cleaned] LA Metro Bus Data.csv', header=True, index=False)

# %% [markdown]
# Now the data is cleaned and has been exported to csv, so let's move to the EDA portion
