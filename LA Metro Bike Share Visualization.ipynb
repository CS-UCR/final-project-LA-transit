# %% [markdown]
# In this notebook, I will visualize the LA Metro data in different ways

# %% [markdown]
# Imports

# %%
import pandas as pd
import folium
from folium.plugins import MarkerCluster

# %% [markdown]
# Read the csv file

# %%
trips_df = pd.read_csv("2020 Q1 Cleaned Bike Data.csv")
trips_df
# Out:
#          trip_id  duration           start_time         end_time  \
# 0      134867493        25  2020-01-01 00:16:00    1/1/2020 0:41
# 1      134867799        35  2020-01-01 00:24:00    1/1/2020 0:59
# 2      134868104        37  2020-01-01 00:31:00    1/1/2020 1:08
# 3      134868103        36  2020-01-01 00:32:00    1/1/2020 1:08
# 4      134868102        35  2020-01-01 00:33:00    1/1/2020 1:08
# ...          ...       ...                  ...              ...
# 76386  140275195        65  2020-03-31 22:48:00  3/31/2020 23:53
# 76387  140274593        23  2020-03-31 23:00:00  3/31/2020 23:23
# 76388  140274893        14  2020-03-31 23:23:00  3/31/2020 23:37
# 76389  140275293        21  2020-03-31 23:37:00  3/31/2020 23:58
# 76390  140275894        23  2020-03-31 23:59:00    4/1/2020 0:22
#
#        start_station  start_lat   start_lon  end_station    end_lat  \
# 0               3063  34.048038 -118.253738         4491  34.047440
# 1               4285        NaN         NaN         4354  34.017681
# 2               4344  34.014309 -118.491341         4322  34.005871
# 3               4344  34.014309 -118.491341         4322  34.005871
# 4               4344  34.014309 -118.491341         4322  34.005871
# ...              ...        ...         ...          ...        ...
# 76386           4460  33.994850 -118.417961         4460  33.994850
# 76387           3076  34.040600 -118.253838         3031  34.044701
# 76388           3031  34.044701 -118.252441         3076  34.040600
# 76389           3076  34.040600 -118.253838         3056  34.037460
# 76390           3056  34.037460 -118.265381         3076  34.040600
#
#           end_lon  bike_id  plan_duration trip_route_category passholder_type  \
# 0     -118.247940    18419             30             One Way    Monthly Pass
# 1     -118.409081    15661              1             One Way    One Day Pass
# 2     -118.429161    15848              1             One Way         Walk-up
# 3     -118.429161    16053              1             One Way         Walk-up
# 4     -118.429161    15694              1             One Way         Walk-up
# ...           ...      ...            ...                 ...             ...
# 76386 -118.417961    15300             30          Round Trip    Monthly Pass
# 76387 -118.252441    16811             30             One Way    Monthly Pass
# 76388 -118.253838    16811             30             One Way    Monthly Pass
# 76389 -118.265381    16811             30             One Way    Monthly Pass
# 76390 -118.253838    18942             30             One Way    Monthly Pass
#
#       bike_type            stop_time  hour  \
# 0      electric  2020-01-01 00:41:00     0
# 1         smart  2020-01-01 00:59:00     0
# 2         smart  2020-01-01 01:08:00     0
# 3         smart  2020-01-01 01:08:00     0
# 4         smart  2020-01-01 01:08:00     0
# ...         ...                  ...   ...
# 76386     smart  2020-03-31 23:53:00    22
# 76387  electric  2020-03-31 23:23:00    23
# 76388  electric  2020-03-31 23:37:00    23
# 76389  electric  2020-03-31 23:58:00    23
# 76390  electric  2020-04-01 00:22:00    23
#
#                             start_station_name    end_station_name
# 0                                  Olive & 5th      Main & Winston
# 1                                    Not Found    Venice & Glendon
# 2      Downtown Santa Monica Expo Line Station  Venice & Inglewood
# 3      Downtown Santa Monica Expo Line Station  Venice & Inglewood
# 4      Downtown Santa Monica Expo Line Station  Venice & Inglewood
# ...                                        ...                 ...
# 76386                       Culver & Inglewood  Culver & Inglewood
# 76387                        9th & Los Angeles           Not Found
# 76388                                Not Found   9th & Los Angeles
# 76389                        9th & Los Angeles        Grand & 14th
# 76390                             Grand & 14th   9th & Los Angeles
#
# [76391 rows x 19 columns]

# %% [markdown]
# # Part One
#
# We will visualize the data and see what areas had more arrivals/departures within a specific hour

# %% [markdown]
# Grab data from a specifc time (in this case 6am)

# %%
def get_trip_counts_by_hour (selected_hour):
    # select the first occurrence of each station id
    locations = trips_df.groupby("start_station").first()
    # and select only the three columns we are interested in
    locations = locations.loc[:, ["start_lat",
                                  "start_lon",
                                  "start_station_name"]]

    subset = trips_df[trips_df["hour"]==selected_hour]
    departure_counts =  subset.groupby("start_station").count()
    # select one column
    departure_counts = departure_counts.iloc[:,[0]]
    # and rename that column
    departure_counts.columns= ["Departure Count"]

    arrival_counts =  subset.groupby("end_station").count().iloc[:,[0]]
    arrival_counts.columns= ["Arrival Count"]
    
    
    trip_counts = departure_counts.join(locations).join(arrival_counts)
    #Let's quickly remove any Nans
    trip_counts.isna().sum()
    trip_counts = trip_counts[trip_counts['start_lat'].notna()]
    trip_counts = trip_counts[trip_counts['start_lon'].notna()]
    
    return trip_counts

#sample to check the function works
get_trip_counts_by_hour(6).head()
# Out:
#                Departure Count  start_lat   start_lon start_station_name  \
# start_station
# 3005                        27  34.048500 -118.258537       7th & Flower
# 3006                         2  34.045540 -118.256668        Olive & 8th
# 3007                         3  34.050480 -118.254593        5th & Grand
# 3008                         4  34.046612 -118.262733     Figueroa & 9th
# 3011                         3  34.041130 -118.267982    Figueroa & Pico
#
#                Arrival Count
# start_station
# 3005                    75.0
# 3006                     1.0
# 3007                    29.0
# 3008                     8.0
# 3011                     4.0

# %% [markdown]
# This function creates a map and will plot the bike data to show departures/arrivals at a specific time
# - Tangerine means there was more departures
# - Teal means there was more arrivals

# %%
def plot_station_counts(trip_counts):
    #Create our map of LA
    arrival_departure_map = folium.Map(location=[34.0522,-118.2437],
                                       zoom_start=11,
                                       tiles='CartoDB dark_matter')
    #Add a circle marker for each row
    for index, row in trip_counts.iterrows():
            net_departures = (row["Departure Count"]-row["Arrival Count"])
        
            #Popup message for each circle
            popup_text = "{}<br> total departures: {}<br> total arrivals: {}<br> net departures: {}"
            popup_text = popup_text.format(row["start_station_name"],
                                           row["Arrival Count"],
                                           row["Departure Count"],
                                           net_departures)
            #radius of the circles
            radius = net_departures/20
            
            if net_departures>0:
                color="#E37222" # tangerine
            else:
                color="#0A8A9F" # teal
            
            #Adds the marker to the map
            folium.CircleMarker(location=(row["start_lat"],
                                          row["start_lon"]),
                                radius=radius,
                                color=color,
                                popup=popup_text,
                                fill=True).add_to(arrival_departure_map)
        
    return arrival_departure_map

# %% [markdown]
# Map at 7 am

# %%
trip_counts = get_trip_counts_by_hour(7)
plot_station_counts(trip_counts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 9am

# %%
trip_counts = get_trip_counts_by_hour(9)
plot_station_counts(trip_counts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 12 o'clock or lunchtime!

# %%
trip_counts = get_trip_counts_by_hour(12)
plot_station_counts(trip_counts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 6pm (leaving work)

# %%
trip_counts = get_trip_counts_by_hour(6)
plot_station_counts(trip_counts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# 8pm

# %%
trip_counts = get_trip_counts_by_hour(8)
plot_station_counts(trip_counts)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
